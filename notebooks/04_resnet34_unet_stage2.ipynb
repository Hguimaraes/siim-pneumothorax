# %%
import os
import gc
import time
import numpy as np
import pandas as pd
from glob import glob
import IPython.display as ipd
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold

os.chdir(os.path.dirname("../src/"))

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import torch
import torch.optim as optim
import torch.nn as nn

# Set seeds for reproducibility
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
from albumentations.pytorch import ToTensor

# %%
from siim_pneumothorax.utils import parse_dicom
from siim_pneumothorax.utils import ConfigObject
from siim_pneumothorax.dataset import get_pneumo_loaders
from siim_pneumothorax.losses import Dice_metric
from siim_pneumothorax.losses import IoU_metric
from siim_pneumothorax.losses import MixedLoss
from siim_pneumothorax.losses import MixedFocalLoss
from siim_pneumothorax.losses import DiceLoss
from siim_pneumothorax.losses import FocalLoss
from siim_pneumothorax.models import VanillaUNet

# %%
import segmentation_models_pytorch as smp

# %% [markdown]
# # Configuration

# %%
# Change 
# CONFIG_SAVE_PATH
# NUM_EPOCHS
# GRID_SIZE
# lr_scheduler

params = {
    # Loader parameters
    'loader_params': {
        'img_size': 256,
        'batch_size': 16,
        'shuffle': True,
        'num_workers': 8,
        'rgb_channel': False,
        'grid_size': 16
    },
    
    # Loss/metric parameters
    'alpha': 0.75,
    'gamma': 2,
    'smooth': 1,
    
    # training parameters
    'n_folds': 3,
    'num_epochs': 50,
    'checkpoint_path': '../models/model_checkpoint',
    'config_save_path': '../models/stage_2/stage_2_config'
}

# %% [markdown]
# # Data preparation

# %%
train_fns = sorted(glob('../data/siim/dicom-images-train/*/*/*.dcm'))
test_fns = sorted(glob('../data/siim/dicom-images-test/*/*/*.dcm'))

# %%
train_rle_codes = pd.read_csv('../data/siim/train-rle.csv')
train_rle_codes.columns = ["ImageId", "EncodedPixels"]
train_rle_codes['has_pneumothorax'] = (train_rle_codes.EncodedPixels != "-1").astype(int)

# %%
train_dataset = pd.DataFrame([parse_dicom(x, train_rle_codes) for x in  train_fns])

# %%
test_dataset = pd.DataFrame([parse_dicom(x, is_training=False) for x in  test_fns])

# %%
train_dataset.dropna(inplace=True)

# %%
# train_dataset = train_dataset.sample(80)

# %% [markdown]
# # Model, Loss function, Optimizer and LR Scheduler

# %%
def get_parameters(params, fold):
    device = 'cuda'
    model = smp.Unet('resnet34', encoder_weights='imagenet', in_channels=1)
    model.load_state_dict(
        torch.load('../models/stage_1/stage_1_config_fold_{}.pt'.format(fold))['model_state_dict']
    )
    model = model.to(device)
    
    # Build optimizer
    optimizer = optim.Adam(model.parameters(), lr=5e-4)
#     optimizer.load_state_dict(
#         torch.load('../models/stage_1/stage_1_config_fold_{}.pt'.format(fold))['optimizer_state_dict']
#     )
    
    # LR scheduler
    lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

    m_loss = MixedLoss(params['smooth'])
    
    return device, model, optimizer, lr_scheduler, m_loss

# %% [markdown]
# # Setup Execution

# %%
def train(config, model, train_loader, valid_loader, 
          loss_fn, lr_scheduler, optimizer, device, debug=True):

    history = {
        'loss': [], 'val_loss': [], 'dice': [], 
        'val_dice': [], 'iou': [], 'val_iou': []
    }
    
    dice_metric = Dice_metric()
    iou_metric = IoU_metric()
    
    for epoch in range(config.num_epochs):
        loss, dice, iou = 0.0, [], []

        start_time = time.time()
        model.train()
        
        for idx, (img, mask) in enumerate(train_loader):
            img = img.type(torch.FloatTensor).to(device)
            mask = mask.type(torch.FloatTensor).to(device)
            optimizer.zero_grad()
            recon_batch = model(img)
            loss_batch = loss_fn(recon_batch, mask)
            dice_batch = dice_metric(recon_batch, mask)
            iou_batch = iou_metric(recon_batch, mask)
            
            loss_batch.backward()
            optimizer.step()

            # Compute metrics to all batch
            loss += loss_batch.item()*len(img)
            dice.append(dice_batch.item())
            iou.append(iou_batch.item())

            if debug:
                print("step: {:4d} of {:4d} | loss: {:.4f} | dice: {:.4f} | iou: {:.4f} ".format(idx + 1, len(train_loader),
                    loss_batch.item()*len(img), dice_batch.item(), iou_batch.item()), end='\r')

        loss /= len(train_loader)
        dice = np.nanmean(dice)
        iou = np.nanmean(iou)

        val_loss, val_dice, val_iou, comparison = evaluate(config, model, valid_loader, loss_fn, device)
        lr_scheduler.step(val_loss)
        elapsed_time = time.time() - start_time
        
        # Display training Metrics
        print('====> Epoch: {:02d} Loss: {:.3f} | val_loss: {:.3f} | val_dice: {:.3f} | val_iou: {:.3f} | Elapsed time: {:.4f}'.format(
          epoch+1, loss, val_loss, val_dice, val_iou, elapsed_time))
        
        # Compute the statistics of the last epoch and save to history
        history['loss'].append(loss)
        history['val_loss'].append(val_loss)
        history['dice'].append(dice)
        history['val_dice'].append(val_dice)
        history['iou'].append(iou)
        history['val_iou'].append(val_iou)

        # Checkpoint the model
        torch.save(model.state_dict(), config.checkpoint_path)
        
    return history

# %%
def evaluate(config, model, heldout_loader, loss_fn, device):
    model.eval()
    heldout_loss = 0
    heldout_dice = []
    heldout_iou = []
    
    dice_metric = Dice_metric()
    iou_metric = IoU_metric()

    with torch.no_grad():
        for i, (img, mask) in enumerate(heldout_loader):
            img = img.type(torch.FloatTensor).to(device)
            mask = mask.type(torch.FloatTensor).to(device)
            recon_batch = model(img)
            heldout_loss += loss_fn(recon_batch, mask).item()*len(img)
            heldout_dice.append(dice_metric(recon_batch, mask).item())
            heldout_iou.append(iou_metric(recon_batch, mask).item())

    heldout_loss /= len(heldout_loader)
    heldout_dice = np.nanmean(heldout_dice)
    heldout_iou = np.nanmean(heldout_iou)
    
    n = min(img.size(0), 16)
    comparison = [img[:n], recon_batch[:n], mask[:n]]
    
    return heldout_loss, heldout_dice, heldout_iou, comparison

# %%
def KFoldTrainer(dataset, params):
    metrics = []
    skf = StratifiedKFold(n_splits=params['n_folds'])

    # Start kFold
    for fold, (train_index, val_index) in enumerate(skf.split(dataset, dataset['has_pneumothorax'])):
        print("======= Fold {}/{} =======".format(fold+1, params['n_folds']))
        train_dataset, val_dataset = dataset.iloc[train_index], dataset.iloc[val_index]
        
        # Balance the dataset
        g = train_dataset.groupby('has_pneumothorax')
        train_dataset = g.apply(lambda x: x.sample(g.size().min()).reset_index(drop=True))
        
        # Configure parameters
        config = {
            'smooth': params["smooth"],
            'num_epochs': params['num_epochs'],
            'checkpoint_path': '{}.pt'.format(params['checkpoint_path']),
            'config_save_path': '{}_fold_{}.pt'.format(params['config_save_path'], fold)
        }

        # Create data loaders
        train_loader = get_pneumo_loaders(df=train_dataset, is_train=True, **params['loader_params'])
        val_loader = get_pneumo_loaders(df=val_dataset, is_train=False, **params['loader_params'])

        # Start training
        config = ConfigObject(**config)
        device, model, optimizer, lr_scheduler, m_loss = get_parameters(params, fold)
        history = train(
            config, model, train_loader, val_loader, 
            m_loss, lr_scheduler, optimizer, device, debug=True
        )

        metrics.append(history)
        torch.save({
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
        }, config.config_save_path)
        print("") # Break line
        break

    return metrics

# %% [markdown]
# # Train

# %%
history = KFoldTrainer(train_dataset, params)
# Out:
# ======= Fold 1/3 =======
# ====> Epoch: 01 Loss: 13.987 | val_loss: 13.252 | val_dice: 0.197 | val_iou: 0.778 | Elapsed time: 68.5340
# ====> Epoch: 02 Loss: 13.951 | val_loss: 13.266 | val_dice: 0.198 | val_iou: 0.778 | Elapsed time: 68.3493
# ====> Epoch: 03 Loss: 13.639 | val_loss: 13.183 | val_dice: 0.207 | val_iou: 0.778 | Elapsed time: 69.5441
# ====> Epoch: 04 Loss: 13.265 | val_loss: 13.827 | val_dice: 0.174 | val_iou: 0.778 | Elapsed time: 70.2230
# ====> Epoch: 05 Loss: 13.551 | val_loss: 13.188 | val_dice: 0.203 | val_iou: 0.778 | Elapsed time: 70.0549
# ====> Epoch: 06 Loss: 13.373 | val_loss: 12.923 | val_dice: 0.221 | val_iou: 0.778 | Elapsed time: 70.2676
# ====> Epoch: 07 Loss: 13.375 | val_loss: 12.685 | val_dice: 0.233 | val_iou: 0.778 | Elapsed time: 70.3657
# ====> Epoch: 08 Loss: 13.434 | val_loss: 14.026 | val_dice: 0.170 | val_iou: 0.778 | Elapsed time: 70.2224
# ====> Epoch: 09 Loss: 13.123 | val_loss: 13.193 | val_dice: 0.210 | val_iou: 0.778 | Elapsed time: 70.5154
# ====> Epoch: 10 Loss: 13.037 | val_loss: 12.148 | val_dice: 0.265 | val_iou: 0.778 | Elapsed time: 70.6021
# ====> Epoch: 11 Loss: 13.170 | val_loss: 12.930 | val_dice: 0.224 | val_iou: 0.778 | Elapsed time: 70.5385
# ====> Epoch: 12 Loss: 12.895 | val_loss: 13.698 | val_dice: 0.187 | val_iou: 0.778 | Elapsed time: 70.7061
# ====> Epoch: 13 Loss: 12.894 | val_loss: 12.798 | val_dice: 0.229 | val_iou: 0.778 | Elapsed time: 70.2808
# ====> Epoch: 14 Loss: 12.964 | val_loss: 12.404 | val_dice: 0.253 | val_iou: 0.778 | Elapsed time: 70.5585
# ====> Epoch: 15 Loss: 12.741 | val_loss: 12.167 | val_dice: 0.264 | val_iou: 0.778 | Elapsed time: 70.8761
# ====> Epoch: 16 Loss: 12.734 | val_loss: 12.008 | val_dice: 0.275 | val_iou: 0.778 | Elapsed time: 70.3195
# ====> Epoch: 17 Loss: 12.588 | val_loss: 12.375 | val_dice: 0.253 | val_iou: 0.778 | Elapsed time: 70.9868
# ====> Epoch: 18 Loss: 12.543 | val_loss: 11.723 | val_dice: 0.289 | val_iou: 0.778 | Elapsed time: 70.3791
# ====> Epoch: 19 Loss: 12.453 | val_loss: 12.097 | val_dice: 0.270 | val_iou: 0.778 | Elapsed time: 70.5624
# ====> Epoch: 20 Loss: 12.385 | val_loss: 11.813 | val_dice: 0.286 | val_iou: 0.778 | Elapsed time: 70.7510
# ====> Epoch: 21 Loss: 12.586 | val_loss: 11.487 | val_dice: 0.303 | val_iou: 0.778 | Elapsed time: 70.4216
# ====> Epoch: 22 Loss: 12.468 | val_loss: 11.851 | val_dice: 0.283 | val_iou: 0.778 | Elapsed time: 71.8260
# ====> Epoch: 23 Loss: 12.278 | val_loss: 12.028 | val_dice: 0.273 | val_iou: 0.778 | Elapsed time: 70.5774
# ====> Epoch: 24 Loss: 12.334 | val_loss: 11.826 | val_dice: 0.284 | val_iou: 0.778 | Elapsed time: 70.9934
# ====> Epoch: 25 Loss: 12.042 | val_loss: 11.965 | val_dice: 0.279 | val_iou: 0.778 | Elapsed time: 70.6658
# ====> Epoch: 26 Loss: 12.226 | val_loss: 11.248 | val_dice: 0.318 | val_iou: 0.778 | Elapsed time: 70.3948
# ====> Epoch: 27 Loss: 12.197 | val_loss: 11.506 | val_dice: 0.305 | val_iou: 0.778 | Elapsed time: 70.2498
# ====> Epoch: 28 Loss: 12.141 | val_loss: 11.771 | val_dice: 0.289 | val_iou: 0.778 | Elapsed time: 70.7832
# ====> Epoch: 29 Loss: 12.175 | val_loss: 11.241 | val_dice: 0.318 | val_iou: 0.778 | Elapsed time: 70.7773
# ====> Epoch: 30 Loss: 12.213 | val_loss: 11.438 | val_dice: 0.308 | val_iou: 0.778 | Elapsed time: 70.4470
# ====> Epoch: 31 Loss: 11.964 | val_loss: 11.144 | val_dice: 0.324 | val_iou: 0.778 | Elapsed time: 70.6828
# ====> Epoch: 32 Loss: 11.746 | val_loss: 11.223 | val_dice: 0.319 | val_iou: 0.778 | Elapsed time: 70.9398
# ====> Epoch: 33 Loss: 12.067 | val_loss: 11.207 | val_dice: 0.322 | val_iou: 0.778 | Elapsed time: 70.5274
# ====> Epoch: 34 Loss: 11.869 | val_loss: 11.223 | val_dice: 0.319 | val_iou: 0.778 | Elapsed time: 70.8083
# ====> Epoch: 35 Loss: 11.972 | val_loss: 11.443 | val_dice: 0.308 | val_iou: 0.778 | Elapsed time: 70.5252
# ====> Epoch: 36 Loss: 11.678 | val_loss: 11.268 | val_dice: 0.319 | val_iou: 0.778 | Elapsed time: 70.7258
# ====> Epoch: 37 Loss: 11.841 | val_loss: 11.271 | val_dice: 0.317 | val_iou: 0.778 | Elapsed time: 70.7972
# ====> Epoch: 38 Loss: 11.980 | val_loss: 11.128 | val_dice: 0.324 | val_iou: 0.778 | Elapsed time: 70.9640
# ====> Epoch: 39 Loss: 11.881 | val_loss: 10.980 | val_dice: 0.334 | val_iou: 0.778 | Elapsed time: 70.9300
# ====> Epoch: 40 Loss: 11.732 | val_loss: 11.130 | val_dice: 0.327 | val_iou: 0.778 | Elapsed time: 70.5509
# ====> Epoch: 41 Loss: 11.784 | val_loss: 11.941 | val_dice: 0.286 | val_iou: 0.778 | Elapsed time: 70.8528
# ====> Epoch: 42 Loss: 11.406 | val_loss: 10.770 | val_dice: 0.346 | val_iou: 0.778 | Elapsed time: 70.7808
# ====> Epoch: 43 Loss: 11.676 | val_loss: 11.112 | val_dice: 0.329 | val_iou: 0.778 | Elapsed time: 70.6554
# ====> Epoch: 44 Loss: 11.792 | val_loss: 11.236 | val_dice: 0.321 | val_iou: 0.778 | Elapsed time: 70.7083
# ====> Epoch: 45 Loss: 11.794 | val_loss: 11.066 | val_dice: 0.330 | val_iou: 0.778 | Elapsed time: 70.9585
# ====> Epoch: 46 Loss: 11.880 | val_loss: 10.858 | val_dice: 0.342 | val_iou: 0.778 | Elapsed time: 70.4370
# ====> Epoch: 47 Loss: 11.587 | val_loss: 10.775 | val_dice: 0.345 | val_iou: 0.778 | Elapsed time: 71.0262
# ====> Epoch: 48 Loss: 11.690 | val_loss: 10.990 | val_dice: 0.334 | val_iou: 0.778 | Elapsed time: 70.8449
# ====> Epoch: 49 Loss: 11.577 | val_loss: 11.002 | val_dice: 0.334 | val_iou: 0.778 | Elapsed time: 71.0601
# ====> Epoch: 50 Loss: 11.366 | val_loss: 10.889 | val_dice: 0.340 | val_iou: 0.778 | Elapsed time: 71.0041

# %% [markdown]
# # Performance Report

# %%
print("Loss = mean: {:.3f} | std: {:.3f}".format(
    np.mean([d['val_loss'][-1] for d in history]),
    np.std([d['val_loss'][-1] for d in history])
))
# Out:
# Loss = mean: 10.889 | std: 0.000

# %%
print("Dice = mean: {:.3f} | std: {:.3f}".format(
    np.mean([d['val_dice'][-1] for d in history]),
    np.std([d['val_dice'][-1] for d in history])
))
# Out:
# Dice = mean: 0.340 | std: 0.000

# %%
print("IoU = mean: {:.3f} | std: {:.3f}".format(
    np.mean([d['val_iou'][-1] for d in history]), 
    np.std([d['val_iou'][-1] for d in history])
))
# Out:
# IoU = mean: 0.778 | std: 0.000

# %% [markdown]
# # Visualization

# %%
model = smp.Unet('resnet34', encoder_weights='imagenet', in_channels=1)
model.load_state_dict(torch.load('../models/stage_2/stage_2_config_fold_0.pt')['model_state_dict'])
model = model.to('cuda')

# %%
train_loader = get_pneumo_loaders(df=train_dataset, is_train=False, **params['loader_params'])

# %%
with torch.no_grad():
    for img, mask in train_loader:
        img = img.to('cuda')
        predicted_mask = model(img)
        break

# %%
idx = 10

p_mask = (nn.Sigmoid()(predicted_mask[idx][0, :, :]).cpu() > .5).int()
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 15))
axes[0].imshow(img[idx, 0, :, :].cpu(), cmap='gray')
axes[1].imshow(mask[idx, 0, :, :], cmap='gray')
axes[2].imshow(p_mask, cmap='gray')
plt.tight_layout()
