# %%
import os
import gc
import time
import numpy as np
import pandas as pd
from glob import glob
import IPython.display as ipd
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold

os.chdir(os.path.dirname("../src/"))

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import torch
import torch.optim as optim
import torch.nn as nn

# Set seeds for reproducibility
SEED = 42
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
from albumentations.pytorch import ToTensor

# %%
from siim_pneumothorax.utils import parse_dicom
from siim_pneumothorax.utils import ConfigObject
from siim_pneumothorax.dataset import get_pneumo_loaders
from siim_pneumothorax.losses import Dice_metric
from siim_pneumothorax.losses import IoU_metric
from siim_pneumothorax.losses import MixedLoss
from siim_pneumothorax.losses import MixedFocalLoss
from siim_pneumothorax.losses import DiceLoss
from siim_pneumothorax.losses import FocalLoss
from siim_pneumothorax.models import VanillaUNet

# %%
import segmentation_models_pytorch as smp

# %% [markdown]
# # Configuration

# %%
# Change 
# CONFIG_SAVE_PATH
# NUM_EPOCHS
# GRID_SIZE
# lr_scheduler

params = {
    # Loader parameters
    'loader_params': {
        'img_size': 512,
        'batch_size': 8,
        'shuffle': True,
        'num_workers': 8,
        'rgb_channel': False,
        'grid_size': 16
    },
    
    # Loss/metric parameters
    'alpha': 0.75,
    'gamma': 2,
    'smooth': 1,
    
    # training parameters
    'n_folds': 3,
    'num_epochs': 50,
    'checkpoint_path': '../models/model_checkpoint',
    'config_save_path': '../models/stage_3/stage_3_config'
}

# %% [markdown]
# # Data preparation

# %%
train_fns = sorted(glob('../data/siim/dicom-images-train/*/*/*.dcm'))
test_fns = sorted(glob('../data/siim/dicom-images-test/*/*/*.dcm'))

# %%
train_rle_codes = pd.read_csv('../data/siim/train-rle.csv')
train_rle_codes.columns = ["ImageId", "EncodedPixels"]
train_rle_codes['has_pneumothorax'] = (train_rle_codes.EncodedPixels != "-1").astype(int)

# %%
train_dataset = pd.DataFrame([parse_dicom(x, train_rle_codes) for x in  train_fns])

# %%
test_dataset = pd.DataFrame([parse_dicom(x, is_training=False) for x in  test_fns])

# %%
train_dataset.dropna(inplace=True)

# %%
# train_dataset = train_dataset.sample(80)

# %% [markdown]
# # Model, Loss function, Optimizer and LR Scheduler

# %%
def get_parameters(params, fold):
    device = 'cuda'
    model = smp.Unet('resnet34', encoder_weights='imagenet', in_channels=1)
    model.load_state_dict(
        torch.load('../models/stage_2/stage_2_config_fold_{}.pt'.format(fold))['model_state_dict']
    )
    model = model.to(device)
    
    # Build optimizer
    optimizer = optim.Adam(model.parameters(), lr=5e-4)
#     optimizer.load_state_dict(
#         torch.load('../models/stage_2/stage_2_config_fold_{}.pt'.format(fold))['optimizer_state_dict']
#     )
    
    # LR scheduler
    lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

    m_loss = MixedLoss(params['smooth'])
    
    return device, model, optimizer, lr_scheduler, m_loss

# %% [markdown]
# # Setup Execution

# %%
def train(config, model, train_loader, valid_loader, 
          loss_fn, lr_scheduler, optimizer, device, debug=True):

    history = {
        'loss': [], 'val_loss': [], 'dice': [], 
        'val_dice': [], 'iou': [], 'val_iou': []
    }
    
    dice_metric = Dice_metric()
    iou_metric = IoU_metric()
    
    for epoch in range(config.num_epochs):
        loss, dice, iou = 0.0, [], []

        start_time = time.time()
        model.train()
        
        for idx, (img, mask) in enumerate(train_loader):
            img = img.type(torch.FloatTensor).to(device)
            mask = mask.type(torch.FloatTensor).to(device)
            optimizer.zero_grad()
            recon_batch = model(img)
            loss_batch = loss_fn(recon_batch, mask)
            dice_batch = dice_metric(recon_batch, mask)
            iou_batch = iou_metric(recon_batch, mask)
            
            loss_batch.backward()
            optimizer.step()

            # Compute metrics to all batch
            loss += loss_batch.item()*len(img)
            dice.append(dice_batch.item())
            iou.append(iou_batch.item())

            if debug:
                print("step: {:4d} of {:4d} | loss: {:.4f} | dice: {:.4f} | iou: {:.4f} ".format(idx + 1, len(train_loader),
                    loss_batch.item()*len(img), dice_batch.item(), iou_batch.item()), end='\r')

        loss /= len(train_loader)
        dice = np.nanmean(dice)
        iou = np.nanmean(iou)

        val_loss, val_dice, val_iou, comparison = evaluate(config, model, valid_loader, loss_fn, device)
        lr_scheduler.step(val_loss)
        elapsed_time = time.time() - start_time
        
        # Display training Metrics
        print('====> Epoch: {:02d} Loss: {:.3f} | val_loss: {:.3f} | val_dice: {:.3f} | val_iou: {:.3f} | Elapsed time: {:.4f}'.format(
          epoch+1, loss, val_loss, val_dice, val_iou, elapsed_time))
        
        # Compute the statistics of the last epoch and save to history
        history['loss'].append(loss)
        history['val_loss'].append(val_loss)
        history['dice'].append(dice)
        history['val_dice'].append(val_dice)
        history['iou'].append(iou)
        history['val_iou'].append(val_iou)

        # Checkpoint the model
        torch.save(model.state_dict(), config.checkpoint_path)
        
    return history

# %%
def evaluate(config, model, heldout_loader, loss_fn, device):
    model.eval()
    heldout_loss = 0
    heldout_dice = []
    heldout_iou = []
    
    dice_metric = Dice_metric()
    iou_metric = IoU_metric()

    with torch.no_grad():
        for i, (img, mask) in enumerate(heldout_loader):
            img = img.type(torch.FloatTensor).to(device)
            mask = mask.type(torch.FloatTensor).to(device)
            recon_batch = model(img)
            heldout_loss += loss_fn(recon_batch, mask).item()*len(img)
            heldout_dice.append(dice_metric(recon_batch, mask).item())
            heldout_iou.append(iou_metric(recon_batch, mask).item())

    heldout_loss /= len(heldout_loader)
    heldout_dice = np.nanmean(heldout_dice)
    heldout_iou = np.nanmean(heldout_iou)
    
    n = min(img.size(0), 16)
    comparison = [img[:n], recon_batch[:n], mask[:n]]
    
    return heldout_loss, heldout_dice, heldout_iou, comparison

# %%
def KFoldTrainer(dataset, params):
    metrics = []
    skf = StratifiedKFold(n_splits=params['n_folds'])

    # Start kFold
    for fold, (train_index, val_index) in enumerate(skf.split(dataset, dataset['has_pneumothorax'])):
        print("======= Fold {}/{} =======".format(fold+1, params['n_folds']))
        train_dataset, val_dataset = dataset.iloc[train_index], dataset.iloc[val_index]
        
        # Balance the dataset
        g = train_dataset.groupby('has_pneumothorax')
        train_dataset = g.apply(lambda x: x.sample(g.size().min()).reset_index(drop=True))
        
        # Configure parameters
        config = {
            'smooth': params["smooth"],
            'num_epochs': params['num_epochs'],
            'checkpoint_path': '{}.pt'.format(params['checkpoint_path']),
            'config_save_path': '{}_fold_{}.pt'.format(params['config_save_path'], fold)
        }

        # Create data loaders
        train_loader = get_pneumo_loaders(df=train_dataset, is_train=True, **params['loader_params'])
        val_loader = get_pneumo_loaders(df=val_dataset, is_train=False, **params['loader_params'])

        # Start training
        config = ConfigObject(**config)
        device, model, optimizer, lr_scheduler, m_loss = get_parameters(params, fold)
        history = train(
            config, model, train_loader, val_loader, 
            m_loss, lr_scheduler, optimizer, device, debug=True
        )

        metrics.append(history)
        torch.save({
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
        }, config.config_save_path)
        print("") # Break line
        break

    return metrics

# %% [markdown]
# # Train

# %%
history = KFoldTrainer(train_dataset, params)
# Out:
# ======= Fold 1/3 =======
# ====> Epoch: 01 Loss: 7.049 | val_loss: 6.704 | val_dice: 0.190 | val_iou: 0.778 | Elapsed time: 253.4438
# ====> Epoch: 02 Loss: 6.792 | val_loss: 6.535 | val_dice: 0.207 | val_iou: 0.778 | Elapsed time: 259.1801
# ====> Epoch: 03 Loss: 6.655 | val_loss: 6.453 | val_dice: 0.217 | val_iou: 0.778 | Elapsed time: 260.7960
# ====> Epoch: 04 Loss: 6.495 | val_loss: 6.330 | val_dice: 0.230 | val_iou: 0.778 | Elapsed time: 261.7617
# ====> Epoch: 05 Loss: 6.659 | val_loss: 6.341 | val_dice: 0.229 | val_iou: 0.778 | Elapsed time: 262.0468
# ====> Epoch: 06 Loss: 6.532 | val_loss: 6.240 | val_dice: 0.242 | val_iou: 0.778 | Elapsed time: 262.2547
# ====> Epoch: 07 Loss: 6.535 | val_loss: 6.249 | val_dice: 0.240 | val_iou: 0.778 | Elapsed time: 263.2809
# ====> Epoch: 08 Loss: 6.450 | val_loss: 6.142 | val_dice: 0.252 | val_iou: 0.778 | Elapsed time: 262.9889
# ====> Epoch: 09 Loss: 6.486 | val_loss: 6.234 | val_dice: 0.241 | val_iou: 0.778 | Elapsed time: 262.7818
# ====> Epoch: 10 Loss: 6.422 | val_loss: 6.148 | val_dice: 0.253 | val_iou: 0.778 | Elapsed time: 264.3103
# ====> Epoch: 11 Loss: 6.406 | val_loss: 6.188 | val_dice: 0.248 | val_iou: 0.778 | Elapsed time: 262.8853
# ====> Epoch: 12 Loss: 6.319 | val_loss: 6.092 | val_dice: 0.260 | val_iou: 0.778 | Elapsed time: 264.3901
# ====> Epoch: 13 Loss: 6.272 | val_loss: 6.182 | val_dice: 0.246 | val_iou: 0.778 | Elapsed time: 264.2274
# ====> Epoch: 14 Loss: 6.266 | val_loss: 6.135 | val_dice: 0.253 | val_iou: 0.778 | Elapsed time: 263.5486
# ====> Epoch: 15 Loss: 6.300 | val_loss: 6.045 | val_dice: 0.266 | val_iou: 0.778 | Elapsed time: 263.8556
# ====> Epoch: 16 Loss: 6.293 | val_loss: 6.061 | val_dice: 0.263 | val_iou: 0.778 | Elapsed time: 265.5844
# ====> Epoch: 17 Loss: 6.313 | val_loss: 5.930 | val_dice: 0.279 | val_iou: 0.778 | Elapsed time: 263.7253
# ====> Epoch: 18 Loss: 6.163 | val_loss: 5.941 | val_dice: 0.277 | val_iou: 0.778 | Elapsed time: 269.8744
# ====> Epoch: 19 Loss: 6.308 | val_loss: 6.350 | val_dice: 0.225 | val_iou: 0.778 | Elapsed time: 267.9217
# ====> Epoch: 20 Loss: 6.259 | val_loss: 5.989 | val_dice: 0.271 | val_iou: 0.778 | Elapsed time: 268.3735
# ====> Epoch: 21 Loss: 6.273 | val_loss: 5.931 | val_dice: 0.277 | val_iou: 0.778 | Elapsed time: 266.3582
# ====> Epoch: 22 Loss: 6.246 | val_loss: 6.011 | val_dice: 0.269 | val_iou: 0.778 | Elapsed time: 268.2586
# ====> Epoch: 23 Loss: 6.108 | val_loss: 6.321 | val_dice: 0.229 | val_iou: 0.778 | Elapsed time: 268.9740
# ====> Epoch: 24 Loss: 6.272 | val_loss: 7.937 | val_dice: 0.123 | val_iou: 0.778 | Elapsed time: 269.5527
# ====> Epoch: 25 Loss: 6.237 | val_loss: 6.078 | val_dice: 0.259 | val_iou: 0.778 | Elapsed time: 271.1660
# ====> Epoch: 26 Loss: 6.138 | val_loss: 5.809 | val_dice: 0.292 | val_iou: 0.778 | Elapsed time: 271.6540
# ====> Epoch: 27 Loss: 6.231 | val_loss: 5.931 | val_dice: 0.278 | val_iou: 0.778 | Elapsed time: 271.2108
# ====> Epoch: 28 Loss: 6.179 | val_loss: 5.878 | val_dice: 0.284 | val_iou: 0.778 | Elapsed time: 271.5631
# ====> Epoch: 29 Loss: 6.254 | val_loss: 5.857 | val_dice: 0.287 | val_iou: 0.778 | Elapsed time: 269.1874
# ====> Epoch: 30 Loss: 6.151 | val_loss: 6.015 | val_dice: 0.267 | val_iou: 0.778 | Elapsed time: 270.7279
# ====> Epoch: 31 Loss: 6.103 | val_loss: 5.961 | val_dice: 0.273 | val_iou: 0.778 | Elapsed time: 270.9703
# ====> Epoch: 32 Loss: 6.085 | val_loss: 5.763 | val_dice: 0.300 | val_iou: 0.778 | Elapsed time: 270.3718
# ====> Epoch: 33 Loss: 6.145 | val_loss: 5.804 | val_dice: 0.295 | val_iou: 0.778 | Elapsed time: 272.8209
# ====> Epoch: 34 Loss: 6.147 | val_loss: 5.838 | val_dice: 0.290 | val_iou: 0.778 | Elapsed time: 269.4586
# ====> Epoch: 35 Loss: 6.136 | val_loss: 5.868 | val_dice: 0.289 | val_iou: 0.778 | Elapsed time: 272.1181
# ====> Epoch: 36 Loss: 6.079 | val_loss: 6.041 | val_dice: 0.264 | val_iou: 0.778 | Elapsed time: 272.0633
# ====> Epoch: 37 Loss: 6.128 | val_loss: 6.271 | val_dice: 0.249 | val_iou: 0.778 | Elapsed time: 274.0631
# ====> Epoch: 38 Loss: 6.114 | val_loss: 5.922 | val_dice: 0.278 | val_iou: 0.778 | Elapsed time: 271.6418
# ====> Epoch: 39 Loss: 6.185 | val_loss: 6.079 | val_dice: 0.259 | val_iou: 0.778 | Elapsed time: 271.4994
# ====> Epoch: 40 Loss: 6.186 | val_loss: 5.918 | val_dice: 0.279 | val_iou: 0.778 | Elapsed time: 271.5132
# ====> Epoch: 41 Loss: 6.150 | val_loss: 5.953 | val_dice: 0.276 | val_iou: 0.778 | Elapsed time: 271.0350
# ====> Epoch: 42 Loss: 6.095 | val_loss: 5.800 | val_dice: 0.294 | val_iou: 0.778 | Elapsed time: 270.9107
# ====> Epoch: 43 Loss: 6.068 | val_loss: 5.806 | val_dice: 0.292 | val_iou: 0.778 | Elapsed time: 270.3962
# ====> Epoch: 44 Loss: 6.076 | val_loss: 5.911 | val_dice: 0.281 | val_iou: 0.778 | Elapsed time: 270.5121
# ====> Epoch: 45 Loss: 6.165 | val_loss: 5.882 | val_dice: 0.286 | val_iou: 0.778 | Elapsed time: 270.6277
# ====> Epoch: 46 Loss: 6.100 | val_loss: 5.860 | val_dice: 0.287 | val_iou: 0.778 | Elapsed time: 270.8978
# ====> Epoch: 47 Loss: 6.078 | val_loss: 6.010 | val_dice: 0.268 | val_iou: 0.778 | Elapsed time: 272.4857
# ====> Epoch: 48 Loss: 6.218 | val_loss: 6.026 | val_dice: 0.265 | val_iou: 0.778 | Elapsed time: 274.8586
# ====> Epoch: 49 Loss: 6.064 | val_loss: 5.911 | val_dice: 0.279 | val_iou: 0.778 | Elapsed time: 276.8273
# ====> Epoch: 50 Loss: 6.133 | val_loss: 5.900 | val_dice: 0.281 | val_iou: 0.778 | Elapsed time: 271.6998

# %% [markdown]
# # Performance Report

# %%
print("Loss = mean: {:.3f} | std: {:.3f}".format(
    np.mean([d['val_loss'][-1] for d in history]),
    np.std([d['val_loss'][-1] for d in history])
))
# Out:
# Loss = mean: 5.900 | std: 0.000

# %%
print("Dice = mean: {:.3f} | std: {:.3f}".format(
    np.mean([d['val_dice'][-1] for d in history]),
    np.std([d['val_dice'][-1] for d in history])
))
# Out:
# Dice = mean: 0.281 | std: 0.000

# %%
print("IoU = mean: {:.3f} | std: {:.3f}".format(
    np.mean([d['val_iou'][-1] for d in history]), 
    np.std([d['val_iou'][-1] for d in history])
))
# Out:
# IoU = mean: 0.778 | std: 0.000

# %% [markdown]
# # Visualization

# %%
model = smp.Unet('resnet34', encoder_weights='imagenet', in_channels=1)
model.load_state_dict(torch.load('../models/stage_3/stage_3_config_fold_0.pt')['model_state_dict'])
model = model.to('cuda')

# %%
train_loader = get_pneumo_loaders(df=train_dataset, is_train=False, **params['loader_params'])

# %%
with torch.no_grad():
    for img, mask in train_loader:
        img = img.to('cuda')
        predicted_mask = model(img)
        break

# %%
idx = 1

p_mask = (nn.Sigmoid()(predicted_mask[idx][0, :, :]).cpu() > .5).int()
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 15))
axes[0].imshow(img[idx, 0, :, :].cpu(), cmap='gray')
axes[1].imshow(mask[idx, 0, :, :], cmap='gray')
axes[2].imshow(p_mask, cmap='gray')
plt.tight_layout()
